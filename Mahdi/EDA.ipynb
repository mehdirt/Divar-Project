# %% [markdown]
# # Divar Real-State Dataset EDA

# %% [markdown]
# ----

# %% [markdown]
# ### Import Essential Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ### Load the data

# %%
data = pd.read_csv("../Divar Dataset/Divar.csv")
# Out:
# /var/folders/9y/lpsdwq1d0bz2t5178sr1rgmr0000gn/T/ipykernel_57922/1735787727.py:1: DtypeWarning: Columns (11,27,29,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("../Divar Dataset/Divar.csv")

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Remove the index column
data = data.drop(columns=["Unnamed: 0"])
data.head(5)
# Out:
#           cat2_slug       cat3_slug city_slug neighborhood_slug  \
# 0    temporary-rent           villa     karaj         mehrshahr
# 1  residential-sell  apartment-sell    tehran           gholhak
# 2  residential-rent  apartment-rent    tehran             tohid
# 3   commercial-rent     office-rent    tehran          elahiyeh
# 4  residential-sell  apartment-sell   mashhad          emamreza
#
#       created_at_month    user_type  \
# 0  2024-08-01 00:00:00  مشاور املاک
# 1  2024-05-01 00:00:00  مشاور املاک
# 2  2024-10-01 00:00:00          NaN
# 3  2024-06-01 00:00:00          NaN
# 4  2024-05-01 00:00:00  مشاور املاک
#
#                                          description  \
# 0  ۵۰۰متر\n۲۰۰متر بنا دوبلکس\n۳خواب\nاستخر آبگرم ...
# 1  دسترسی عالی به مترو و شریعتی \nمشاعات تمیز \nب...
# 2                                    تخلیه پایان ماه
# 3  فرشته تاپ لوکیشن\n۹۰ متر موقعیت اداری\nیک اتاق...
# 4  هلدینگ ساختمانی اکبری\n\nهمراه شما هستیم برای ...
#
#                                               title rent_mode  rent_value  \
# 0  باغ ویلا اجاره روزانه استخر داخل لشکرآباد سهیلیه       NaN         NaN
# 1                           ۶۰ متر قلهک فول امکانات       NaN         NaN
# 2                          آپارتمان ۳ خوابه ۱۳۲ متر     مقطوع  26000000.0
# 3           فرشته ۹۰ متر دفتر کار مدرن موقعیت اداری     مقطوع  95000000.0
# 4                  ۱۱۵ متری/شمالی رو به آفتاب/اکبری       NaN         NaN
#
#    ... property_type regular_person_capacity extra_person_capacity  \
# 0  ...           NaN                     4.0                     6
# 1  ...           NaN                     NaN                   NaN
# 2  ...           NaN                     NaN                   NaN
# 3  ...           NaN                     NaN                   NaN
# 4  ...           NaN                     NaN                   NaN
#
#    cost_per_extra_person rent_price_on_regular_days  \
# 0               350000.0                  1500000.0
# 1                    NaN                        NaN
# 2                    NaN                        NaN
# 3                    NaN                        NaN
# 4                    NaN                        NaN
#
#    rent_price_on_special_days rent_price_at_weekends location_latitude  \
# 0                3.500000e+09              3500000.0         35.811684
# 1                         NaN                    NaN               NaN
# 2                         NaN                    NaN         35.703865
# 3                         NaN                    NaN               NaN
# 4                         NaN                    NaN               NaN
#
#    location_longitude  location_radius
# 0           50.936600            500.0
# 1                 NaN            500.0
# 2           51.373459              NaN
# 3                 NaN              NaN
# 4                 NaN              NaN
#
# [5 rows x 60 columns]

# %%
# # Analyzing data using d-tale
# import dtale

# d = dtale.show(data)
# d.open_browser()

# %%
# Data basic information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 60 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   cat2_slug                   1000000 non-null  object
#  1   cat3_slug                   999999 non-null   object
#  2   city_slug                   999998 non-null   object
#  3   neighborhood_slug           437139 non-null   object
#  4   created_at_month            1000000 non-null  object
#  5   user_type                   288882 non-null   object
#  6   description                 1000000 non-null  object
#  7   title                       999946 non-null   object
#  8   rent_mode                   352994 non-null   object
#  9   rent_value                  351322 non-null   float64
#  10  rent_to_single              19 non-null       object
#  11  rent_type                   103961 non-null   object
#  12  price_mode                  573606 non-null   object
#  13  price_value                 568346 non-null   float64
#  14  credit_mode                 352994 non-null   object
#  15  credit_value                352095 non-null   float64
#  16  rent_credit_transform       352985 non-null   object
#  17  transformable_price         352894 non-null   object
#  18  transformable_credit        352085 non-null   float64
#  19  transformed_credit          72409 non-null    float64
#  20  transformable_rent          351248 non-null   float64
#  21  transformed_rent            72409 non-null    float64
#  22  land_size                   186396 non-null   float64
#  23  building_size               980394 non-null   float64
#  24  deed_type                   253458 non-null   object
#  25  has_business_deed           34679 non-null    object
#  26  floor                       541748 non-null   object
#  27  rooms_count                 845899 non-null   object
#  28  total_floors_count          304352 non-null   object
#  29  unit_per_floor              302283 non-null   object
#  30  has_balcony                 506411 non-null   object
#  31  has_elevator                541749 non-null   object
#  32  has_warehouse               728155 non-null   object
#  33  has_parking                 728156 non-null   object
#  34  construction_year           815828 non-null   object
#  35  is_rebuilt                  529470 non-null   object
#  36  has_water                   33444 non-null    object
#  37  has_warm_water_provider     379500 non-null   object
#  38  has_electricity             33445 non-null    object
#  39  has_gas                     33430 non-null    object
#  40  has_heating_system          368969 non-null   object
#  41  has_cooling_system          350619 non-null   object
#  42  has_restroom                406913 non-null   object
#  43  has_security_guard          31312 non-null    object
#  44  has_barbecue                31198 non-null    object
#  45  building_direction          323923 non-null   object
#  46  has_pool                    29390 non-null    object
#  47  has_jacuzzi                 28728 non-null    object
#  48  has_sauna                   28479 non-null    object
#  49  floor_material              405984 non-null   object
#  50  property_type               27057 non-null    object
#  51  regular_person_capacity     29870 non-null    float64
#  52  extra_person_capacity       24009 non-null    object
#  53  cost_per_extra_person       10241 non-null    float64
#  54  rent_price_on_regular_days  18068 non-null    float64
#  55  rent_price_on_special_days  10463 non-null    float64
#  56  rent_price_at_weekends      13551 non-null    float64
#  57  location_latitude           655608 non-null   float64
#  58  location_longitude          655608 non-null   float64
#  59  location_radius             339699 non-null   float64
# dtypes: float64(17), object(43)
# memory usage: 457.8+ MB

# %% [markdown]
# -> Dataset 1M rows and contains 60 columns:
# - 43 object (23 string | 16 boolean | 4 mixed)
# - 17 float

# %%
# Statistical description of categorical columns
data.describe(include='object')
# Out:
#                cat2_slug       cat3_slug city_slug neighborhood_slug  \
# count            1000000          999999    999998            437139
# unique                 6              16       421              1188
# top     residential-sell  apartment-sell    tehran      elahiyehblvd
# freq              558708          303385    190904              7076
#
#            created_at_month    user_type  \
# count               1000000       288882
# unique                   46            2
# top     2024-07-01 00:00:00  مشاور املاک
# freq                 133219       256006
#
#                                               description        title  \
# count                                             1000000       999946
# unique                                             989449       904092
# top     ❌فروش ویلا و زمین زیرقیمت منطقه و بدون واسطه ب...  خانه ویلایی
# freq                                                  220         1867
#
#        rent_mode rent_to_single  ... has_restroom has_security_guard  \
# count     352994             19  ...       406913              31312
# unique         3              2  ...            4                  2
# top        مقطوع           True  ...   squat_seat              False
# freq      292081             18  ...       219393              24631
#
#        has_barbecue building_direction has_pool has_jacuzzi has_sauna  \
# count         31198             323923    29390       28728     28479
# unique            2                  5        2           2         2
# top           False              south    False       False     False
# freq          23377             159453    25669       26455     27084
#
#        floor_material property_type extra_person_capacity
# count          405984         27057                 24009
# unique              8             5                    36
# top           ceramic        jungle                     2
# freq           307821         16614                  6849
#
# [4 rows x 43 columns]

# %%
# Statistical description of numerical columns
data.describe(include='number')
# Out:
#          rent_value   price_value  credit_value  transformable_credit  \
# count  3.513220e+05  5.683460e+05  3.520950e+05          3.520850e+05
# mean   4.102299e+10  1.736537e+10  4.872084e+10          4.872222e+10
# std    3.807534e+12  5.878739e+11  4.341346e+12          4.341407e+12
# min    0.000000e+00  0.000000e+00  0.000000e+00          0.000000e+00
# 25%    1.111110e+05  1.400000e+09  1.000000e+08          1.000000e+08
# 50%    5.000000e+06  2.840000e+09  2.500000e+08          2.500000e+08
# 75%    1.200000e+07  5.900000e+09  5.000000e+08          5.000000e+08
# max    1.000000e+15  1.000000e+14  1.000000e+15          1.000000e+15
#
#        transformed_credit  transformable_rent  transformed_rent     land_size  \
# count        7.240900e+04        3.512480e+05      7.240900e+04  1.863960e+05
# mean         8.557025e+09        4.103164e+10      1.619934e+07  4.165480e+03
# std          2.064576e+12        3.807935e+12      5.217890e+07  1.218927e+05
# min          0.000000e+00        0.000000e+00      0.000000e+00  1.000000e+00
# 25%          2.000000e+08        1.111110e+05      1.000000e+06  1.100000e+02
# 50%          4.000000e+08        5.000000e+06      6.000000e+06  1.950000e+02
# 75%          8.500000e+08        1.200000e+07      1.500000e+07  2.800000e+02
# max          5.555556e+14        1.000000e+15      3.000000e+09  1.000000e+07
#
#        building_size  regular_person_capacity  cost_per_extra_person  \
# count   9.803940e+05             29870.000000           1.024100e+04
# mean    4.440648e+03                 6.557650           1.209785e+10
# std     1.367118e+05                 7.698655           1.103482e+12
# min     1.000000e+00                 1.000000           0.000000e+00
# 25%     7.500000e+01                 3.000000           5.000000e+04
# 50%     1.030000e+02                 4.000000           1.000000e+05
# 75%     1.650000e+02                 7.000000           2.000000e+05
# max     1.000000e+07                50.000000           1.111111e+14
#
#        rent_price_on_regular_days  rent_price_on_special_days  \
# count                1.806800e+04                1.046300e+04
# mean                 1.389016e+11                2.355548e+10
# std                  7.042335e+12                1.542049e+12
# min                  0.000000e+00                0.000000e+00
# 25%                  4.000000e+05                6.000000e+05
# 50%                  8.000000e+05                1.200000e+06
# 75%                  1.600000e+06                2.500000e+06
# max                  5.006007e+14                1.111111e+14
#
#        rent_price_at_weekends  location_latitude  location_longitude  \
# count            1.355100e+04      655608.000000       655608.000000
# mean             3.156551e+10          34.982108           51.629743
# std              2.434942e+12           2.379169            3.160920
# min              0.000000e+00          23.626478           40.162369
# 25%              5.500000e+05          34.553551           50.677175
# 50%              1.100000e+06          35.723312           51.345791
# 75%              2.500000e+06          36.307013           51.805291
# max              2.002503e+14          40.358055           74.511620
#
#        location_radius
# count    339699.000000
# mean        465.149147
# std         125.896250
# min           0.000000
# 25%         500.000000
# 50%         500.000000
# 75%         500.000000
# max         500.000000

# %% [markdown]
# Vallue-Counts of non-numeric columns:

# %%
# Show Value-Count of non-numeric columns
for col in data.select_dtypes(include='object').columns:
    print(f"{data[col].value_counts()}")
    print("-" * 50)
# Out:
# cat2_slug
# residential-sell        558708
# residential-rent        276558
# commercial-rent          76567
# commercial-sell          38861
# temporary-rent           29903
# real-estate-services     19403
# Name: count, dtype: int64
# --------------------------------------------------
# cat3_slug
# apartment-sell                        303385
# apartment-rent                        211880
# plot-old                              133570
# house-villa-sell                      121753
# house-villa-rent                       64678
# shop-rent                              45993
# shop-sell                              21855
# office-rent                            21418
# suite-apartment                        16465
# presell                                15781
# villa                                  12899
# industry-agriculture-business-sell     11851
# industry-agriculture-business-rent      9155
# office-sell                             5155
# partnership                             3622
# workspace                                539
# Name: count, dtype: int64
# --------------------------------------------------
# city_slug
# tehran           190904
# mashhad           69032
# karaj             49367
# shiraz            37141
# isfahan           36953
#                   ...
# goli-dagh             5
# maraveh-tapeh         5
# khoour                3
# yanghagh              2
# tatar-olya            1
# Name: count, Length: 421, dtype: int64
# --------------------------------------------------
# neighborhood_slug
# elahiyehblvd                7076
# poonak                      5393
# ghasemabad                  5216
# saadat-abad                 4686
# bolvartoos                  4684
#                             ...
# nowruzi                        1
# saberhanan                     1
# parastar-bandar-e-anzali       1
# amir-shahid                    1
# jamaran-rasht                  1
# Name: count, Length: 1188, dtype: int64
# --------------------------------------------------
# created_at_month
# 2024-07-01 00:00:00    133219
# 2024-08-01 00:00:00    132396
# 2024-10-01 00:00:00    126387
# 2024-06-01 00:00:00    125624
# 2024-11-01 00:00:00    121456
# 2024-09-01 00:00:00    121432
# 2024-12-01 00:00:00    116452
# 2024-05-01 00:00:00    108759
# 2024-04-01 00:00:00      7187
# 2024-03-01 00:00:00      1881
# 2024-02-01 00:00:00      1211
# 2025-01-01 00:00:00      1139
# 2024-01-01 00:00:00       942
# 2023-12-01 00:00:00       532
# 2023-11-01 00:00:00       353
# 2023-10-01 00:00:00       213
# 2023-09-01 00:00:00       177
# 2025-02-01 00:00:00       148
# 2023-08-01 00:00:00       117
# 2023-07-01 00:00:00        96
# 2023-06-01 00:00:00        66
# 2023-05-01 00:00:00        53
# 2023-03-01 00:00:00        25
# 2023-04-01 00:00:00        23
# 2023-01-01 00:00:00        17
# 2023-02-01 00:00:00        17
# 2022-12-01 00:00:00        11
# 2022-11-01 00:00:00         9
# 2022-08-01 00:00:00         9
# 2022-05-01 00:00:00         7
# 2022-10-01 00:00:00         6
# 2022-09-01 00:00:00         6
# 2025-03-01 00:00:00         5
# 2022-04-01 00:00:00         5
# 2022-06-01 00:00:00         4
# 2022-07-01 00:00:00         4
# 2022-02-01 00:00:00         2
# 2021-12-01 00:00:00         2
# 2021-06-01 00:00:00         1
# 2020-12-01 00:00:00         1
# 2020-02-01 00:00:00         1
# 2022-01-01 00:00:00         1
# 2021-05-01 00:00:00         1
# 2021-02-01 00:00:00         1
# 2022-03-01 00:00:00         1
# 2021-11-01 00:00:00         1
# Name: count, dtype: int64
# --------------------------------------------------
# user_type
# مشاور املاک    256006
# شخصی            32876
# Name: count, dtype: int64
# --------------------------------------------------
# description
# ❌فروش ویلا و زمین زیرقیمت منطقه و بدون واسطه با اقساط بدون بهره❌\n✅خوش ساخت\n✅انشعابات نصب\n✅ویوابدی جنگل\n✅مناسب برای سکونت دائم\n✅اسناد و مدارک ملک تکمیل میباشد\n✅حیاطسازی بسیار زیبا و عالی\n✅داخل شهرک برند با گیت نگهبانی ۲۴ساعته\n♦️تخفیف ویژه پای قرارداد\n♦️تهاتر با انواع خودرو انجام میشود\n♦️عضو اتحادیه املاک با صدور کد رهگیری\nجهت کسب اطلاعات بیشتر و بازدید تماس بگیرید \nمشاور راهنما :خانم اسماعیلی                                                                               220
# برای اطلاعات بیشتر تماس بگیرید                                                                                                                                                                                                                                                                                                                                                                                                                                                                       117
# تخفیف پای معامله                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      94
# فول امکانات                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           92
# تماس بگیرید                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           86
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# راه ماشین رو دارد\nنزدیک به بافت شهری و جاده اصلی طالقان\n۴۰ عدد درخت لوله کشی شده قطره ای\nسهمیه آب دارد\nتوضیحات بیشتر تماس بگیرید                                                                                                                                                                                                                                                                                                                                                                   1
# با سلام فروش یک قطعه زمین باغ شهری دور تا دور دیوار و درب همراه با اتاق نگهبانی و گوه استخر زده شده سکو گرفته شده که بسیار باغ از تمامی باغ ها بالا تر باشد کف صاف شد\nداری برق دائم و آب هفتگی و نگهبانی ۲۴ ساعته \nآدرس دقیق زمین \nپلیس راه پل فسا باغ نشاط قبل از تیون فرهنگیان ۱۳ فاز یک میشه اشخاصی که اطلاع دارن میدونن که قیمت فاز یک بیشتر از مابقی فاز ها هست \nقیمتی که زدم زیر قیمت مجموعه هست فقط به دلیل اینکه پولشو نیاز دارم وگر نمیفروختم به این قیمت \nبا مشتری واقعی کنار میام      1
# سلام\nساختمان در حال ساخت\nگچ و خاک شده\n۳ طبقه روی پارکینگ\n۲۰۰متر زمین\n۱۲۷ متر زیربنا\nلوله کی فاضلاب انجام شده\nلوله کشی برق انجام شده\nعلمک گاز هم داره\nبصورت کامل و ۶ دانگ بفروش میرسد\nموقعیت در خوانسار شهرک اندیشه\nمناسب سازنده ها و سرمایه گذاران عزیز❤️                                                                                                                                                                                                                                   1
# ⚫۲۰۷متر خوش نقشه \n⚫پلان کاملا تفکیکی \n⚫۳خواب با ویوی مشجر \n⚫سالن زیبا با دید سبز و دنج\n⚫تراس کاربری و قابل چیدمان \n⚫اشپزخانه خانه نیمه فرنیش \n\n☑لابی شیک و لابی من\n☑مشاعات کامل و فعال \n☑۲پارکینگ سندی \n☑ساختمان کم واحد و آرام\n\n⚜مالک خوب و منعطف ⚜                                                                                                                                                                                                                                       1
# ⚜️املاک بزرگ میلیارد⚜️\n✅️۴۰ متر یک خواب\n✅️نور و نقشه فوق العاده\n✅️سالن پرده خور (خوش چیدمان)\n✅️دارای بالکن\n✅️طبقه دوم \n✅️فول بازسازی \n✅️مناسب مجرد و زوج\n✅️واحد تخلیه و آماده تحویل میباشد\n✅️تصاویر متعلق به واحد است                                                                                                                                                                                                                                                                         1
# Name: count, Length: 989449, dtype: int64
# --------------------------------------------------
# title
# خانه ویلایی                                           1867
# زمین مسکونی                                           1596
# زمین                                                  1424
# زمین کشاورزی                                           929
# آپارتمان                                               849
#                                                       ...
# اجاره اپارتمان دو خواب                                   1
# فرصت خرید آپارتمان های بر Almas2/تیپ های مختلف/GEM       1
# ۶۸متر/۲خواب/فردوس غرب                                    1
# خانه ویلای بفروش می رسد                                  1
# ۴۰ متر/ یک خواب /فول بازسازی                             1
# Name: count, Length: 904092, dtype: int64
# --------------------------------------------------
# rent_mode
# مقطوع     292081
# مجانی      59241
# توافقی      1672
# Name: count, dtype: int64
# --------------------------------------------------
# rent_to_single
# True     18
# False     1
# Name: count, dtype: int64
# --------------------------------------------------
# rent_type
# rent_credit    103814
# full_credit       147
# Name: count, dtype: int64
# --------------------------------------------------
# price_mode
# مقطوع     566444
# توافقی      5260
# مجانی       1902
# Name: count, dtype: int64
# --------------------------------------------------
# credit_mode
# مقطوع     349231
# مجانی       2864
# توافقی       899
# Name: count, dtype: int64
# --------------------------------------------------
# rent_credit_transform
# False    326561
# True      26424
# Name: count, dtype: int64
# --------------------------------------------------
# transformable_price
# False    279778
# True      73116
# Name: count, dtype: int64
# --------------------------------------------------
# deed_type
# single_page          194262
# written_agreement     31873
# other                 20288
# multi_page             6466
# unselect                569
# Name: count, dtype: int64
# --------------------------------------------------
# has_business_deed
# False    17428
# True     17251
# Name: count, dtype: int64
# --------------------------------------------------
# floor
#  2       128432
#  1       119495
#  3       109256
#  4        71885
#  5        37586
#  0        35834
#  6        13774
#  7         5708
#  -1        4462
#  8         3297
#  10        2299
#  9         2192
#  11        1473
#  12        1232
#  13         834
#  14         782
#  30+        675
#  15         450
#  16         313
#  17         269
#  20         213
#  18         188
#  19         153
#  21         115
#  25         102
#  22          86
#  2.0         86
#  23          76
#  1.0         70
#  3.0         68
#  30          62
#  24          61
#  4.0         42
#  27          35
#  28          32
#  26          25
#  0.0         21
#  29          20
#  5.0         18
#  6.0         10
#  7.0          5
#  10.0         3
# -1.0          2
#  20.0         1
#  18.0         1
#  8.0          1
#  22.0         1
#  14.0         1
#  9.0          1
#  11.0         1
# Name: count, dtype: int64
# --------------------------------------------------
# rooms_count
# دو              404050
# یک              192083
# سه              138633
# بدون اتاق        75898
# چهار             21371
# پنج یا بیشتر     13864
# Name: count, dtype: int64
# --------------------------------------------------
# total_floors_count
# 4           89526
# 5           79911
# 3           52752
# 6           28877
# 2           22733
# 7            8271
# 8            4585
# 14           3046
# 10           2914
# 9            2005
# 12           1782
# 11           1399
# 13           1064
# 15            993
# 16            715
# 20            619
# 18            455
# 25            431
# 21            322
# 19            310
# 17            263
# 30+           233
# 30            208
# 24            167
# 29            148
# 22            137
# unselect      125
# 26             60
# 4.0            55
# 3.0            43
# 23             42
# 27             40
# 5.0            40
# 28             28
# 6.0            16
# 2.0            14
# 7.0             5
# 8.0             3
# 10.0            3
# 14.0            2
# 20.0            2
# 11.0            2
# 13.0            2
# 25.0            1
# 12.0            1
# 21.0            1
# 19.0            1
# Name: count, dtype: int64
# --------------------------------------------------
# unit_per_floor
# 2              119794
# 1               97712
# 4               36918
# 3               31423
# 6                4899
# 5                4811
# 8                3471
# more_than_8      2083
# 7                 926
# unselect          246
# Name: count, dtype: int64
# --------------------------------------------------
# has_balcony
# true        392096
# false        88855
# True         20692
# False         4545
# unselect       223
# Name: count, dtype: int64
# --------------------------------------------------
# has_elevator
# True     365148
# False    176601
# Name: count, dtype: int64
# --------------------------------------------------
# has_warehouse
# True     582313
# False    145842
# Name: count, dtype: int64
# --------------------------------------------------
# has_parking
# True     552542
# False    175614
# Name: count, dtype: int64
# --------------------------------------------------
# construction_year
# ۱۴۰۳           116260
# ۱۳۹۰            59139
# ۱۴۰۲            58424
# ۱۴۰۰            53674
# ۱۳۹۵            53029
# ۱۳۹۸            38207
# ۱۳۹۷            36326
# ۱۳۹۶            35487
# ۱۴۰۱            35328
# ۱۳۸۵            34065
# ۱۳۹۹            29594
# ۱۳۹۳            29094
# ۱۳۹۲            26130
# ۱۳۹۴            26110
# ۱۳۸۸            24268
# ۱۳۸۰            23480
# قبل از ۱۳۷۰     20637
# ۱۳۸۹            16755
# ۱۳۹۱            16316
# ۱۳۸۷            14136
# ۱۳۸۶            13468
# ۱۳۸۳             9894
# ۱۳۸۴             8494
# ۱۳۷۵             7247
# ۱۳۸۲             6965
# ۱۳۷۱             5531
# ۱۳۸۱             3590
# ۱۳۷۸             3025
# ۱۳۷۹             2415
# ۱۳۷۷             2117
# ۱۳۷۲             1914
# ۱۳۷۳             1827
# ۱۳۷۶             1593
# ۱۳۷۴             1289
# Name: count, dtype: int64
# --------------------------------------------------
# is_rebuilt
# False    353191
# True     176279
# Name: count, dtype: int64
# --------------------------------------------------
# has_water
# False    17083
# True     16361
# Name: count, dtype: int64
# --------------------------------------------------
# has_warm_water_provider
# package         205641
# water_heater    141082
# powerhouse       31395
# unselect          1382
# Name: count, dtype: int64
# --------------------------------------------------
# has_electricity
# False    17167
# True     16278
# Name: count, dtype: int64
# --------------------------------------------------
# has_gas
# False    17297
# True     16133
# Name: count, dtype: int64
# --------------------------------------------------
# has_heating_system
# shoofaj          201356
# heater           119771
# duct_split        22047
# floor_heating      7717
# split              5845
# fan_coil           5065
# fireplace          4050
# unselect           3118
# Name: count, dtype: int64
# --------------------------------------------------
# has_cooling_system
# water_cooler       219266
# air_conditioner     52341
# split               38708
# duct_split          29373
# unselect             5917
# fan_coil             5014
# Name: count, dtype: int64
# --------------------------------------------------
# has_restroom
# squat_seat    219393
# squat         179437
# seat            7455
# unselect         628
# Name: count, dtype: int64
# --------------------------------------------------
# has_security_guard
# False    24631
# True      6681
# Name: count, dtype: int64
# --------------------------------------------------
# has_barbecue
# False    23377
# True      7821
# Name: count, dtype: int64
# --------------------------------------------------
# building_direction
# south       159453
# north       142009
# east         12111
# west          7143
# unselect      3207
# Name: count, dtype: int64
# --------------------------------------------------
# has_pool
# False    25669
# True      3721
# Name: count, dtype: int64
# --------------------------------------------------
# has_jacuzzi
# False    26455
# True      2273
# Name: count, dtype: int64
# --------------------------------------------------
# has_sauna
# False    27084
# True      1395
# Name: count, dtype: int64
# --------------------------------------------------
# floor_material
# ceramic             307821
# stone                38395
# carpet               17696
# mosaic               14611
# wood_parquet         14419
# laminate_parquet      9582
# floor_covering        1793
# unselect              1667
# Name: count, dtype: int64
# --------------------------------------------------
# property_type
# jungle             16614
# beach               3990
# other               3832
# jungle-mountain     2399
# mountain             222
# Name: count, dtype: int64
# --------------------------------------------------
# extra_person_capacity
# 2      6849
# 1      3910
# 4      2843
# 3      2086
# 5      2062
# 6      1165
# 10     1066
# 0       923
# 30+     724
# 8       617
# 7       429
# 20      304
# 15      262
# 12      208
# 9       104
# 25       78
# 14       61
# 11       52
# 16       41
# 29       38
# 24       32
# 13       31
# 18       23
# 23       14
# 22       14
# 17       13
# 26       12
# 28       12
# 27        9
# 19        9
# 21        6
# 5.0       4
# 4.0       3
# 2.0       3
# 1.0       1
# 6.0       1
# Name: count, dtype: int64
# --------------------------------------------------

# %% [markdown]
# **According to our observations:**
# - Some columns contain a mix of numerical and string values:<br>
# `floor` - `total_floors_count`, `has_balcony`, `extra_person_capacity`
#
# - Some columns' values are stored as string, but they're number and must be converted to integers (or bin them).
#
# - Some string columns are **Farsi**.<br>
# `user_type` - `rent_mode` - `price_mode` - `credit_mode` - `construction_year` - `rooms_count`
#
# - Some columns contain a value called '`unselect`' which can be converted to **NaN**.
#
# - There are two time-related columns.<br>
#  `created_at_month` - `construction_year`
#
# - There are two coloumn, `rooms_count` and `unit_per_floor`, that might be better to bin them.

# %% [markdown]
# #### Check Memory Usage

# %%
print(f"{data.memory_usage(deep=True).sum() / 1e6} Mb")# Current memory usage
# Out:
# 2729.286698 Mb

# %%
#‌ ‌Reduce‌ ‌memory‌ ‌usage‌ ‌by‌ ‌converting‌ ‌column‌ ‌data‌ ‌types‌ ‌
def reduce_memory_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    # Compute memory usage
    start_mem = df.memory_usage().sum() / 1024**2
    # Iterate through each column
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
    # Compute memory usage after reduction
    end_mem = df.memory_usage().sum() / 1024**2
    # Print out the difference between memory usage before and after
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
# Reduce memory usage
data = reduce_memory_usage(data)
# Out:
# Mem. usage decreased to 385.28 Mb (15.8% reduction)
# /var/folders/9y/lpsdwq1d0bz2t5178sr1rgmr0000gn/T/ipykernel_4649/180345247.py:22: RuntimeWarning: overflow encountered in cast
#   if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
# /var/folders/9y/lpsdwq1d0bz2t5178sr1rgmr0000gn/T/ipykernel_4649/180345247.py:22: RuntimeWarning: overflow encountered in cast
#   if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
# /var/folders/9y/lpsdwq1d0bz2t5178sr1rgmr0000gn/T/ipykernel_4649/180345247.py:22: RuntimeWarning: overflow encountered in cast
#   if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
# /var/folders/9y/lpsdwq1d0bz2t5178sr1rgmr0000gn/T/ipykernel_4649/180345247.py:22: RuntimeWarning: overflow encountered in cast
#   if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
# /var/folders/9y/lpsdwq1d0bz2t5178sr1rgmr0000gn/T/ipykernel_4649/180345247.py:22: RuntimeWarning: overflow encountered in cast
#   if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
# /var/folders/9y/lpsdwq1d0bz2t5178sr1rgmr0000gn/T/ipykernel_4649/180345247.py:22: RuntimeWarning: overflow encountered in cast
#   if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
# /var/folders/9y/lpsdwq1d0bz2t5178sr1rgmr0000gn/T/ipykernel_4649/180345247.py:22: RuntimeWarning: overflow encountered in cast
#   if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
# /var/folders/9y/lpsdwq1d0bz2t5178sr1rgmr0000gn/T/ipykernel_4649/180345247.py:22: RuntimeWarning: overflow encountered in cast
#   if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
# /var/folders/9y/lpsdwq1d0bz2t5178sr1rgmr0000gn/T/ipykernel_4649/180345247.py:22: RuntimeWarning: overflow encountered in cast
#   if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
# /var/folders/9y/lpsdwq1d0bz2t5178sr1rgmr0000gn/T/ipykernel_4649/180345247.py:22: RuntimeWarning: overflow encountered in cast
#   if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
# /var/folders/9y/lpsdwq1d0bz2t5178sr1rgmr0000gn/T/ipykernel_4649/180345247.py:22: RuntimeWarning: overflow encountered in cast
#   if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
# /var/folders/9y/lpsdwq1d0bz2t5178sr1rgmr0000gn/T/ipykernel_4649/180345247.py:22: RuntimeWarning: overflow encountered in cast
#   if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
# /var/folders/9y/lpsdwq1d0bz2t5178sr1rgmr0000gn/T/ipykernel_4649/180345247.py:22: RuntimeWarning: overflow encountered in cast
#   if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:

# %%
print(f"{data.memory_usage(deep=True).sum() / 1e6} Mb") # New memory usage
# Out:
# 2653.286698 Mb

# %% [markdown]
# #### Check Missing Values

# %% [markdown]
# More than **90%**
#
# -> 19 Columns

# %%
# Print Columns that has more than 90% missing values
temp = (data.isna().sum() / len(data) * 100).astype(np.float32)
temp[temp > 90].sort_values(ascending=False)
# Out:
# rent_to_single                99.998100
# cost_per_extra_person         98.975899
# rent_price_on_special_days    98.953697
# rent_price_at_weekends        98.644897
# rent_price_on_regular_days    98.193199
# extra_person_capacity         97.599098
# property_type                 97.294296
# has_sauna                     97.152100
# has_jacuzzi                   97.127197
# has_pool                      97.060997
# regular_person_capacity       97.013000
# has_barbecue                  96.880203
# has_security_guard            96.868797
# has_gas                       96.656998
# has_water                     96.655602
# has_electricity               96.655502
# has_business_deed             96.532097
# transformed_credit            92.759102
# transformed_rent              92.759102
# dtype: float32

# %% [markdown]
# More than **75%**
#
# -> 21 Columns

# %%
# Print Columns that has more than 75% missing values
temp = (data.isna().sum() / len(data) * 100).astype(np.float32)
temp[temp > 75].sort_values(ascending=False)
# Out:
# rent_to_single                99.998100
# cost_per_extra_person         98.975899
# rent_price_on_special_days    98.953697
# rent_price_at_weekends        98.644897
# rent_price_on_regular_days    98.193199
# extra_person_capacity         97.599098
# property_type                 97.294296
# has_sauna                     97.152100
# has_jacuzzi                   97.127197
# has_pool                      97.060997
# regular_person_capacity       97.013000
# has_barbecue                  96.880203
# has_security_guard            96.868797
# has_gas                       96.656998
# has_water                     96.655602
# has_electricity               96.655502
# has_business_deed             96.532097
# transformed_rent              92.759102
# transformed_credit            92.759102
# rent_type                     89.603897
# land_size                     81.360397
# dtype: float32

# %% [markdown]
# More than **50%**
#
# -> 41 Columns

# %%
# Print Columns that has more than 50% missing values
temp = (data.isna().sum() / len(data) * 100).astype(np.float32)
temp[temp > 50].sort_values(ascending=False)
# Out:
# rent_to_single                99.998100
# cost_per_extra_person         98.975899
# rent_price_on_special_days    98.953697
# rent_price_at_weekends        98.644897
# rent_price_on_regular_days    98.193199
# extra_person_capacity         97.599098
# property_type                 97.294296
# has_sauna                     97.152100
# has_jacuzzi                   97.127197
# has_pool                      97.060997
# regular_person_capacity       97.013000
# has_barbecue                  96.880203
# has_security_guard            96.868797
# has_gas                       96.656998
# has_water                     96.655602
# has_electricity               96.655502
# has_business_deed             96.532097
# transformed_rent              92.759102
# transformed_credit            92.759102
# rent_type                     89.603897
# land_size                     81.360397
# deed_type                     74.654198
# user_type                     71.111801
# unit_per_floor                69.771698
# total_floors_count            69.564796
# building_direction            67.607697
# location_radius               66.030098
# has_cooling_system            64.938103
# transformable_rent            64.875198
# rent_value                    64.867798
# transformable_credit          64.791496
# credit_value                  64.790497
# transformable_price           64.710602
# rent_credit_transform         64.701500
# credit_mode                   64.700600
# rent_mode                     64.700600
# has_heating_system            63.103100
# has_warm_water_provider       62.049999
# floor_material                59.401600
# has_restroom                  59.308701
# neighborhood_slug             56.286098
# dtype: float32

# %% [markdown]
# Less than **50%**
#
# -> 19 Columns

# %%
# Print Columns that has less than 50% missing values
temp = (data.isna().sum() / len(data) * 100).astype(np.float32)
temp[temp <= 50].sort_values(ascending=False)
# Out:
# has_balcony           49.358898
# is_rebuilt            47.053001
# floor                 45.825199
# has_elevator          45.825100
# price_value           43.165401
# price_mode            42.639400
# location_latitude     34.439201
# location_longitude    34.439201
# has_warehouse         27.184500
# has_parking           27.184401
# construction_year     18.417200
# rooms_count           15.410100
# building_size          1.960600
# title                  0.005400
# city_slug              0.000200
# cat3_slug              0.000100
# description            0.000000
# created_at_month       0.000000
# cat2_slug              0.000000
# dtype: float32

# %%
del temp

# %% [markdown]
# The **Bar chart** of the number of non-missing values in each column.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The dendogram of missingness describing correlation of variables by grouping them:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Check Duplicate Rows

# %%
data.duplicated().sum()
# Out:
# np.int64(106)

# %% [markdown]
# -> There are 106 duplicated rows.

# %% [markdown]
# #### Check Outliers

# %% [markdown]
# Check for outliers and distributions using histogram on numeric features

# %%
data.hist(figsize=(20, 20), bins=30)
plt.show()

# %% [markdown]
# Check for existing outlier using Boxplots on numeric featrues

# %%
num_cols = data.select_dtypes(include='number')

plt.figure(figsize=(20, 10))
sns.boxplot(data=num_cols)
plt.xticks(rotation=45)
plt.title("Box Plot of Numerical Columns")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Check Correlation

# %%
# See linear (Pearson) correlation between numeric columns
numeric_df = data.select_dtypes(include=['number'])

plt.figure(figsize=(20,10))
sns.heatmap(numeric_df.corr(), cmap='crest', annot=True, fmt='.2f')
# Out:
# <Axes: >

# %% [markdown]
# These features are highly correlated: <br>
# 1- rent_value <-> transformable_rent <-> transformable_credit <-> transformed_credit <-> credit_value <br>
# 2- rent_price_on_regular_days <-> rent_price_on_special_days <br>
# 3- lands_size <-> building_size <br>

# %% [markdown]
# #### Plot Properties Map Using Scatter Plot

# %%
# Scatter plot of geographical coordinated
plt.figure(figsize=(15, 10))
sns.scatterplot(data=data, x='location_longitude', y='location_latitude')
# Out:
# <Axes: xlabel='location_longitude', ylabel='location_latitude'>

# %%
# Show which properties has business deed
plt.figure(figsize=(15, 10))
sns.scatterplot(data=data, x='location_longitude', y='location_latitude', hue='has_business_deed')
# Out:
# <Axes: xlabel='location_longitude', ylabel='location_latitude'>

# %%
# Show which properties are advertized by agencies or private owners
plt.figure(figsize=(15, 10))
sns.scatterplot(data=data, x='location_longitude', y='location_latitude', hue='user_type', palette='Set2')
# Out:
# <Axes: xlabel='location_longitude', ylabel='location_latitude'>
