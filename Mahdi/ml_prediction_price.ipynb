# %% [markdown]
# # Machine Learning - Price Prediction
#
# ---

# %% [markdown]
# #### **Load  Data & libraries**

# %%
import dtale
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../Divar Dataset/Divar.csv')
data.drop('Unnamed: 0', axis=1, inplace=True)
# Out:
# /var/folders/9y/lpsdwq1d0bz2t5178sr1rgmr0000gn/T/ipykernel_58796/1300283319.py:1: DtypeWarning:
#
# Columns (11,27,29,53) have mixed types. Specify dtype option on import or set low_memory=False.

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ## Train the Models

# %% [markdown]
# ## Evaluate Models
